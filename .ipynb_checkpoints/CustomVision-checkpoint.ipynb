# %%
import urllib.parse, json, http.client

url = "southcentralus.api.cognitive.microsoft.com"
params = urllib.parse.urlencode({
    'name':'Car Brand Classifier',
    'description':'Classifying cars by looking at the front'
})
endpoint = "/customvision/v2.0/Training/projects?%s" % params
headers = {
    'Training-key':'bfda991de78a40cdbd13223ed356ef5e'
}

try:
    conn = http.client.HTTPSConnection(url)
    conn.request('POST', endpoint, '', headers)
    response = conn.getresponse()
    jsonData = response.read()
    data = json.loads(jsonData)
    print(data)
    conn.close()
except Exception as ex:
    print(ex)
# Out:
# "\ntry:\n    conn = http.client.HTTPSConnection(url)\n    conn.request('POST', endpoint, '', headers)\n    response = conn.getresponse()\n    jsonData = response.read()\n    data = json.loads(jsonData)\n    print(data)\n    conn.close()\nexcept Exception as ex:\n    print(ex)"

# %%
#project_id = data['Id']
project_id = '1bff7f53-b139-4c33-9e8a-f0859f141652'
print(project_id)
# Out:
# 1bff7f53-b139-4c33-9e8a-f0859f141652

# %%
tags_params = urllib.parse.urlencode({
    'name':'VW',
    'description':'VolksWagen car fronts'
})
tags_endpoint = "/customvision/v2.0/Training/projects/{0}/tags?{1}".format(project_id, tags_params)

try:
    conn = http.client.HTTPSConnection(url)
    conn.request('POST', tags_endpoint, '', headers)
    response = conn.getresponse()
    jsonData = response.read()
    data = json.loads(jsonData)
    print(data)
    conn.close()
except Exception as ex:
    print(ex)
# Out:
# {'id': 'ccf01985-568e-4a24-a313-507df106bf1d', 'name': 'VW', 'description': 'VolksWagen car fronts', 'imageCount': 0}

# %%
get_tags_endpoint = "/customvision/v2.0/Training/projects/{0}/tags".format(project_id)

try:
    conn = http.client.HTTPSConnection(url)
    conn.request('GET', get_tags_endpoint, '', headers)
    response = conn.getresponse()
    jsonData = response.read()
    data = json.loads(jsonData)
    print(json.dumps(data, indent = 2))
    conn.close()
except Exception as ex:
    print(ex)
# Out:
# [
#   {
#     "id": "fb2a13e5-cba2-4097-a227-2194a6c95e05",
#     "name": "Mercedes",
#     "description": "Mercedes car fronts",
#     "imageCount": 5
#   },
#   {
#     "id": "265d81c5-3ace-41c4-ae3d-69e0199a0c22",
#     "name": "Audi",
#     "description": "Audi car fronts",
#     "imageCount": 5
#   },
#   {
#     "id": "85e52aed-59a4-4d8d-956f-c99abcebc424",
#     "name": "Tesla",
#     "description": "Tesla car fronts",
#     "imageCount": 5
#   },
#   {
#     "id": "f1c82196-088d-438d-aa85-cdcc83f93891",
#     "name": "BMW",
#     "description": "BMW car fronts",
#     "imageCount": 5
#   }
# ]

# %%
import os

upload_images_headers = {
    'Training-key':'bfda991de78a40cdbd13223ed356ef5e',
    'Content-Type':'application/octet-stream'
}

for tag in data['Tags']:
    for file in os.listdir('CV_Images_2/' + tag['Name']):
        fileName = 'CV_Images_2/{0}/{1}'.format(tag['Name'], file)
        with open(fileName, 'rb') as body:
            upload_images_params = urllib.parse.urlencode({
                'tagIds':tag['Id']
            })
            upload_images_endpoint = '/customvision/v1.2/Training/projects/{0}/images?{1}'.format(project_id, upload_images_params)
            try:
                conn = http.client.HTTPSConnection(url)
                conn.request('POST', upload_images_endpoint, body, upload_images_headers)
                response = conn.getresponse()
                jsonData = response.read()
                upload_images_data = json.loads(jsonData)
                print(json.dumps(upload_images_data, indent = 2))
                conn.close()
            except Exception as ex:
                print(ex)
# Out:
# {
#   "IsBatchSuccessful": true,
#   "Images": [
#     {
#       "SourceUrl":
ri": "https://irisscuprodstore.blob.core.windows.net/i-1bff7f53b1394c339e8af0859f141652/i-c2d244a6c58842afb299b48b94a4c773?sv=2017-04-17&sr=b&sig=6PTYN%2BU3uaH%2BkYiDphy0vJQ3H%2BuZfSheE9NbFoQr%2B8E%3D&se=2018-08-12T12%3A01%3A59Z&sp=r",
#         "ThumbnailUri": "https://irisscuprodstore.blob.core.windows.net/i-1bff7f53b1394c339e8af0859f141652/t-c2d244a6c58842afb299b48b94a4c773?sv=2017-04-17&sr=b&sig=S5PrRCknHUK7UXJ6QI27nUIkQdSc82hHP3iRudjHwNE%3D&se=2018-08-12T12%3A01%3A59Z&sp=r",
#         "Tags": [
#           {
#             "TagId": "f1c82196-088d-438d-aa85-cdcc83f93891",
#             "Created": "2018-08-11T12:01:59.9996966"
#           }
#         ]
#       }
#     }
#   ]
# }

# %%
train_headers = {
    'Training-key':'bfda991de78a40cdbd13223ed356ef5e'
}
train_endpoint = '/customvision/v2.0/Training/projects/{0}/train'.format(project_id)

try:
    conn = http.client.HTTPSConnection(url)
    conn.request('POST', train_endpoint, '', train_headers)
    response = conn.getresponse()
    jsonData = response.read()
    data = json.loads(jsonData)
    print(json.dumps(data, indent = 2))
    conn.close()
except Exception as ex:
    print(ex)
# Out:
# {
#   "Id": "3a7c4e1f-4862-47b0-9acb-813242c4503d",
#   "Name": "Iteration 1",
#   "IsDefault": false,
#   "Status": "Training",
#   "Created": "2018-08-10T11:51:48.4133333",
#   "LastModified": "2018-08-13T10:20:27.443586",
#   "ProjectId": "1bff7f53-b139-4c33-9e8a-f0859f141652",
#   "Exportable": false,
#   "DomainId": null
# }

# %%
get_project_headers = {
    'Training-key':'bfda991de78a40cdbd13223ed356ef5e'
}
get_project_endpoint = '/customvision/v2.0/Training/projects/{0}/iterations'.format(project_id)

try:
    conn = http.client.HTTPSConnection(url)
    conn.request('GET', get_project_endpoint, '', get_project_headers)
    response = conn.getresponse()
    jsonData = response.read()
    data = json.loads(jsonData)
    print(json.dumps(data, indent = 2))
    conn.close()
except Exception as ex:
    print(ex)
# Out:
# [
#   {
#     "id": "3a7c4e1f-4862-47b0-9acb-813242c4503d",
#     "name": "Iteration 1",
#     "isDefault": false,
#     "status": "Completed",
#     "created": "2018-08-10T11:51:48.4133333",
#     "lastModified": "2018-08-13T10:20:28.5336074",
#     "trainedAt": "2018-08-13T10:20:28.5180193",
#     "projectId": "1bff7f53-b139-4c33-9e8a-f0859f141652",
#     "exportable": false,
#     "domainId": "ee85a74c-405e-4adc-bb47-ffa8ca0c9f31"
#   }
# ]

# %%
iteration_id = data[0]['Id']

get_iteration_headers = {
    'Training-key':'bfda991de78a40cdbd13223ed356ef5e'
}
get_iteration_params = urllib.parse.urlencode({
    'threshold':0.5
})
get_iteration_endpoint = '/customvision/v2.0/Training/projects/{0}/iterations/{1}/performance?{2}'.format(project_id, iteration_id, get_iteration_params)

try:
    conn = http.client.HTTPSConnection(url)
    conn.request('GET', get_iteration_endpoint, '', get_iteration_headers)
    response = conn.getresponse()
    jsonData = response.read()
    get_iteration_data = json.loads(jsonData)
    print(json.dumps(get_iteration_data, indent = 2))
    conn.close()
except Exception as ex:
    print(ex)
# Out:
# {
#   "perTagPerformance": [
#     {
#       "id": "265d81c5-3ace-41c4-ae3d-69e0199a0c22",
#       "name": "Audi",
#       "precision": 1.0,
#       "precisionStdDeviation": 0.0,
#       "recall": 0.8333333,
#       "recallStdDeviation": 0.235702246
#     },
#     {
#       "id": "f1c82196-088d-438d-aa85-cdcc83f93891",
#       "name": "BMW",
#       "precision": 0.8888889,
#       "precisionStdDeviation": 0.157134831,
#       "recall": 0.8333333,
#       "recallStdDeviation": 0.235702246
#     },
#     {
#       "id": "fb2a13e5-cba2-4097-a227-2194a6c95e05",
#       "name": "Mercedes",
#       "precision": 0.8333333,
#       "precisionStdDeviation": 0.235702246,
#       "recall": 0.8333333,
#       "recallStdDeviation": 0.235702246
#     },
#     {
#       "id": "85e52aed-59a4-4d8d-956f-c99abcebc424",
#       "name": "Tesla",
#       "precision": 0.8888889,
#       "precisionStdDeviation": 0.157134831,
#       "recall": 0.8333333,
#       "recallStdDeviation": 0.235702246
#     }
#   ],
#   "precision": 0.869047642,
#   "precisionStdDeviation": 0.102408633,
#   "recall": 0.8333333,
#   "recallStdDeviation": 0.117851123
# }

# %%
prediction_key = 'e5b5e0c4d2e147d9836dfe3bed2f7aa5'
image_url = 'https://unpluggedperformance.com/wp-content/uploads/2016/08/Unplugged-Performance-Refresh-Front-Fascia-Tesla-Model-S-Solid-Black-8.jpg'

prediction_headers = {
    'Prediction-Key':prediction_key,
    'Content-Type':'application/json'
}
'''
prediction_headers = {
    'Prediction-Key':prediction_key,
    'Content-Type':'multipart/form-data'
}
'''
prediction_params = urllib.parse.urlencode({
    'iterationId':iteration_id
})
# prediction_endpoint = '/customvision/v2.0/Prediction/{0}/url?{1}'.format(project_id, prediction_params)
# if you want to use a local image, use this endpoint instead
# prediction_endpoint = '/customvision/v2.0/Prediction/{0}/image?{1}'.format(project_id, prediction_params)

# if you don't want to store images, use one of these endpoints instead
prediction_endpoint = '/customvision/v2.0/Prediction/{0}/url/nostore?{1}'.format(project_id, prediction_params)
# if you want to use a local image, use this endpoint instead
# prediction_endpoint = '/customvision/v2.0/Prediction/{0}/image/nostore?{1}'.format(project_id, prediction_params)

prediction_body = {
    'Url':image_url
}

try:
    conn = http.client.HTTPSConnection(url)
    conn.request('POST', prediction_endpoint, str(prediction_body), prediction_headers)
    response = conn.getresponse()
    jsonData = response.read()
    prediction_data = json.loads(jsonData)
    print(json.dumps(prediction_data, indent = 2))
    conn.close()
except Exception as ex:
    print(ex)
# Out:
# {
#   "id": "dad8aac6-1aaa-4ecd-b5bb-2676d5aa69c9",
#   "project": "1bff7f53-b139-4c33-9e8a-f0859f141652",
#   "iteration": "3a7c4e1f-4862-47b0-9acb-813242c4503d",
#   "created": "2018-08-13T11:36:19.0409654Z",
#   "predictions": [
#     {
#       "probability": 0.9792242,
#       "tagId": "85e52aed-59a4-4d8d-956f-c99abcebc424",
#       "tagName": "Tesla"
#     },
#     {
#       "probability": 0.0118127344,
#       "tagId": "fb2a13e5-cba2-4097-a227-2194a6c95e05",
#       "tagName": "Mercedes"
#     },
#     {
#       "probability": 0.00749720726,
#       "tagId": "f1c82196-088d-438d-aa85-cdcc83f93891",
#       "tagName": "BMW"
#     },
#     {
#       "probability": 0.00146585074,
#       "tagId": "265d81c5-3ace-41c4-ae3d-69e0199a0c22",
#       "tagName": "Audi"
#     }
#   ]
# }
